-- %% [markdown]
-- **\## Observando os dados**

-- %%
SELECT TOP(20)*
FROM Portfolio_Project_SQL..CovidVaccinations
WHERE continent IS NOT NULL
ORDER BY 3, 4
-- Out:
-- (20 rows affected)
-- Total execution time: 00:00:09.608
-- ...
